# %% [markdown]
# # extakeLearning

# %% [markdown]
# making our extake go vroom faster is like super duper important<br>
# we got things to do and places to be so we gotta minimize<br>
# so making our extake go vroom in the absolute fastest possible time is key to minimizing cold start shoot and turnaround time<br>
# i got things to do and places to be (clash) and this task has a pretty easy to define reward function so ts sounds perfect for **reinforcement learning**<br>
# <!-- TODO -->
